# %%
import pandas as pd

# %%
dataframe0 = pd.read_csv('../Data/CC Report.csv')
dataframe1 = pd.read_csv('../Data/February 2018 Giving.csv')

# %%
dataframe0.head()
# Out:
#    Constituent ID               Name Soft Credit Recipient Soft Credit Amount  \
# 0          307441        Simon Blank                   NaN                NaN
# 1          108437  Carolyn C. Sewell        Sewell, Joseph             100.00
# 2          320852         Anita Moss                   NaN                NaN
# 3          124744    Louis A. Trosch                   NaN                NaN
# 4          319742      Mark I. Brown                   NaN                NaN
#
#   Assigned Solicitor  Gift ID  Gift Date Gift Amount   Pay Method Gift Type  \
# 0                NaN    87519   3/4/2018      500.00  Credit Card      Cash
# 1                NaN    87500   3/7/2018      100.00  Credit Card      Cash
# 2                NaN    87513  3/10/2018       25.00  Credit Card      Cash
# 3       Ellis, Erica    87468   3/5/2018       83.33  Credit Card  Pay-Cash
# 4                NaN    87470   3/5/2018      100.00  Credit Card  Pay-Cash
#
# ...

# %%
dataframe1.head()
# Out:
#    Constituent ID  First Name Last Name           Organization Name  \
# 0          320386         NaN       NaN  PPG Architectural Coatings
# 1          320184        Lynn   Shearon                         NaN
# 2          320538        Cory    Pethel                         NaN
# 3          311356        Paul  Johansen                         NaN
# 4          320536  Shaumanick  McDuffie                         NaN
#
#   Soft Credit Constituent Soft Credit Constituent_1 Soft Credit Constituent_2  \
# 0                     NaN                       NaN                       NaN
# 1                     NaN                       NaN                       NaN
# 2                     NaN                       NaN                       NaN
# 3                     NaN                       NaN                       NaN
# 4                     NaN                       NaN                       NaN
#
#   Gift Date Gift Amount     Gift Type             Fund           Campaign  \
# ...
